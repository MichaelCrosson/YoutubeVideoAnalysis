# %% [markdown]
# ## Nico KEY AIzaSyDeNjpxlKcwb8XE7v9UO3BY46gioPxyXss

# %%
import pandas as pd
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api._errors import NoTranscriptFound, TranscriptsDisabled, VideoUnavailable
import os
import time, random
from datetime import datetime
import ssl
import isodate
import re

# %%
# Initialize the YouTube API client
API_KEY = 'AIzaSyDeNjpxlKcwb8XE7v9UO3BY46gioPxyXss'
youtube = build('youtube', 'v3', developerKey=API_KEY)

# %% [markdown]
# ## Obtain Channel IDs

# %%
channel_names_search = ['@Mrwhosetheboss', '@mkbhd', '@unboxtherapy', '@Dave2D', '@MaryBautista', '@JerryRigEverything',
                  '@ThisIsTechToday','@CreatedbyEllaYT', '@ChigzTech']

# %%
def get_channel_id_from_name(youtube, channel_name, retries=3):
    attempt = 0
    while attempt < retries:
        try:
            search_response = youtube.search().list(
                q=channel_name,
                part='snippet',
                maxResults=1,
                type='channel'
            ).execute()
            items = search_response.get('items')
            if items:
                return items[0]['id']['channelId']
            else:
                print(f"No channel found for {channel_name}")
                return None
        except Exception as e:
            attempt += 1
            print(f"Attempt {attempt} failed for {channel_name}: {e}")
            if attempt < retries:
                time.sleep(2 ** attempt + random.uniform(0, 1))  # Exponential backoff with jitter
            else:
                print(f"Failed to retrieve channel ID for {channel_name} after {retries} attempts.")
                return None


# Retrieve channel IDs
channel_data = []
for name in channel_names_search:
    channel_id = get_channel_id_from_name(youtube, name)
    if channel_id:
        channel_data.append({'channel_name': name, 'channel_id': channel_id})
    time.sleep(1)  # Pause to respect API rate limits

# Create DataFrame
df_channels_ids = pd.DataFrame(channel_data)

# Save DataFrame to CSV
csv_path = 'Channels_IDs.csv'
df_channels_ids.to_csv(csv_path, index=False)

print(f"DataFrame created and saved to {csv_path}")
# Out:
# DataFrame created and saved to Channels_IDs.csv

# %%
df_channels_ids
# Out:
#           channel_name                channel_id
# 0      @Mrwhosetheboss  UCMiJRAwDNSNzuYeN2uWa0pA
# 1               @mkbhd  UCBJycsmduvYEL83R_U4JriQ
# 2        @unboxtherapy  UCsTcErHg8oDvUnTzoqsYeNw
# 3              @Dave2D  UCVYamHliCI9rw1tHR1xbkfw
# 4        @MaryBautista  UCst-F1upPxpie6i_jA6vpRw
# 5  @JerryRigEverything  UCWFKCr40YwOZQx8FHU_ZqqQ
# 6     @ThisIsTechToday  UCEAMLkMKtq6YhmaZdUT1ywA
# 7     @CreatedbyEllaYT  UCfuwnVrJuKnqb-2hQZbctsQ
# 8           @ChigzTech  UC-v54XQalOcx5yco3aTixrg

# %% [markdown]
# ## MetaData

# %%
import chardet

# Detect the file encoding
with open('videos_selected.csv', 'rb') as f:
    result = chardet.detect(f.read())

input_csv = 'videos_selected.csv'
base_video_df = pd.read_csv(input_csv, encoding=result['encoding'])

# %%
# Function to fetch video details
def fetch_video_details(video_id):
    try:
        # Fetch video details
        request = youtube.videos().list(part="snippet,statistics,contentDetails", id=video_id)
        response = request.execute()
        
        if not response['items']:
            return None
        
        video = response['items'][0]
        snippet = video['snippet']
        stats = video['statistics']
        content_details = video['contentDetails']
        
        # Extract required fields
        return {
            'video_id': video_id,
            'video_title': snippet.get('title', ''),
            'published_datetime': snippet.get('publishedAt', ''),
            'duration': content_details.get('duration', ''),
            'view_count': int(stats.get('viewCount', 0)),
            'like_count': int(stats.get('likeCount', 0)),
            'dislike_count': int(stats.get('dislikeCount', 0)),  # YouTube no longer provides dislike count
            'comment_count': int(stats.get('commentCount', 0)),
            'description': snippet.get('description', ''),
            'thumbnail_url': snippet.get('thumbnails', {}).get('high', {}).get('url', '')
        }
    except Exception as e:
        print(f"Error fetching details for video ID {video_id}: {e}")
        return None

# Fetch details for all videos
video_details_list = []
for _, row in base_video_df.iterrows():
    video_id = row['video_id']
    channel_name = row['channel_name']  # Add channel_name from the base DataFrame
    details = fetch_video_details(video_id)
    if details:
        details['channel_name'] = channel_name  # Include channel_name in the results
        video_details_list.append(details)

# Convert to DataFrame and reorder columns
output_df = pd.DataFrame(video_details_list, columns=[
    'channel_name', 'video_id', 'video_title', 'published_datetime', 
    'duration', 'view_count', 'like_count', 'dislike_count', 
    'comment_count', 'description', 'thumbnail_url'
])

# Save to a new CSV file
output_df.to_csv("Video_Details.csv", index=False)

print("Video details have been saved to 'Video_Details.csv'.")
# Out:
# Video details have been saved to 'Video_Details.csv'.

# %%
output_df.head()
# Out:
#       channel_name     video_id  \
# 0  @Mrwhosetheboss  neIYdLysqlk
# 1  @Mrwhosetheboss  YX8ks42Azn8
# 2  @Mrwhosetheboss  4RcThoRG46c
# 3  @Mrwhosetheboss  vSIbvJB4WdI
# 4  @Mrwhosetheboss  cRPBp2tRxFY
#
#                                          video_title    published_datetime  \
# 0              I tested the Craziest Xiaomi Gadgets!  2024-11-13T12:04:54Z
# 1            The TRIPLE FOLDING phone has a Problem.  2024-10-26T14:06:50Z
# 2             I tested every Celebrity Tech product!  2024-10-05T10:52:18Z
# 3  iPhone 16 Pro Max vs Samsung S24 Ultra Camera ...  2024-09-19T11:44:30Z
# 4  iPhone 16 / 16 Pro Unboxing - Testing every ne...  2024-09-18T12:00:50Z
#
#    duration  view_count  like_count  dislike_count  comment_count  \
# 0  PT27M53S     6679521      219704              0           8890
# 1  PT12M54S     3464013      111736              0           5932
# 2  PT27M15S     5872358      185517              0           5921
# 3  PT16M44S     3852255      116115              0          10790
# 4  PT21M40S     4292702      125122              0           8474
#
#                                          description  \
# 0  I'm still genuinely in shock how great some of...
# 1  This phone has a LOT of good....and a LOT of b...
# 2  Celebrity tech from Ronaldo, Mbappe, Will Smit...
# 3  iPhone 16 Pro / Pro Max camera test comparison...
# 4  Unboxing and testing the iPhone 16 Pro Max, iP...
#
#                                       thumbnail_url
# 0  https://i.ytimg.com/vi/neIYdLysqlk/hqdefault.jpg
# 1  https://i.ytimg.com/vi/YX8ks42Azn8/hqdefault.jpg
# 2  https://i.ytimg.com/vi/4RcThoRG46c/hqdefault.jpg
# 3  https://i.ytimg.com/vi/vSIbvJB4WdI/hqdefault.jpg
# 4  https://i.ytimg.com/vi/cRPBp2tRxFY/hqdefault.jpg

# %%
output_df.groupby(['channel_name'])['video_id'].count()
# Out:
# channel_name
# @ChigzTech             5
# @CreatedbyEllaYT       5
# @Dave2D                5
# @JerryRigEverything    5
# @MaryBautista          5
# @Mrwhosetheboss        5
# @ThisIsTechToday       5
# @mkbhd                 5
# @unboxtherapy          5
# Name: video_id, dtype: int64

# %% [markdown]
# ## Transcript API

# %%
# Read the video details file
video_details_file = "Video_Details.csv"
video_details_df = pd.read_csv(video_details_file)

# Function to fetch transcript for a video
def fetch_transcript(video_id):
    try:
        # Fetch the transcript
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        # Combine all transcript text into one string
        transcript_text = " ".join([item['text'] for item in transcript])
        return transcript_text
    except TranscriptsDisabled:
        return "Transcript disabled for this video."
    except VideoUnavailable:
        return "Video unavailable."
    except NoTranscriptFound:
        return "No transcript found."
    except Exception as e:
        return f"Error: {e}"

# Fetch transcripts for all videos
transcripts = []
for _, row in video_details_df.iterrows():
    video_id = row['video_id']
    print(f"Fetching transcript for video_id: {video_id}")
    transcript_text = fetch_transcript(video_id)
    transcripts.append(transcript_text)

# Add the transcripts as a new column
video_details_df['transcript'] = transcripts

# Save to a new file
transcript_file = "Video_Transcripts.csv"
video_details_df.to_csv(transcript_file, index=False)

print(f"Transcripts have been saved to '{transcript_file}'.")
# Out:
# Fetching transcript for video_id: neIYdLysqlk
# Fetching transcript for video_id: YX8ks42Azn8
# Fetching transcript for video_id: 4RcThoRG46c
# Fetching transcript for video_id: vSIbvJB4WdI
# Fetching transcript for video_id: cRPBp2tRxFY
# Fetching transcript for video_id: z19HM7ANZlo
# Fetching transcript for video_id: Yv_S7KrOlfk
# Fetching transcript for video_id: nK9zxuXa3OA
# Fetching transcript for video_id: MRtg6A1f2Ko
# Fetching transcript for video_id: h3BKjZMGoIw
# Fetching transcript for video_id: hPf2qu5U6F8
# Fetching transcript for video_id: QptbdEci-m8
# Fetching transcript for video_id: _ybbXIksjUk
# Fetching transcript for video_id: G7o7Qz08RrI
# Fetching transcript for video_id: PCEmUPqSK4k
# Fetching transcript for video_id: b4x8boB2KdI
# Fetching transcript for video_id: qExcc92zHfo
# Fetching transcript for video_id: 1rJa-0YOkwk
# Fetching transcript for video_id: tYJWcs-qnAc
# Fetching transcript for video_id: 1OHZTFseggA
# Fetching transcript for video_id: CHv-oKQcjF8
# Fetching transcript for video_id: 9a42bdlFRxM
# Fetching transcript for video_id: pk9RKCRdWyc
# Fetching transcript for video_id: H17T4dH7-W0
# Fetching transcript for video_id: 8AuAv0eQlBI
# Fetching transcript for video_id: FZzZatxb9KQ
# Fetching transcript for video_id: PIun_aBsRMA
# Fetching transcript for video_id: IFthVfjoVOc
# Fetching transcript for video_id: VS66VOUmoKQ
# Fetching transcript for video_id: qYztDs8vPBg
# Fetching transcript for video_id: CwaZ47RUjoU
# Fetching transcript for video_id: TJqTr8_w588
# Fetching transcript for video_id: ThmKbekcisg
# Fetching transcript for video_id: ciR9HfGTlf0
# Fetching transcript for video_id: awY7eX8rguw
# Fetching transcript for video_id: ZoTCq6zunl0
# Fetching transcript for video_id: e_utOqzf5j0
# Fetching transcript for video_id: FLrbO71yQUA
# Fetching transcript for video_id: CUOzCh_Pcrg
# Fetching transcript for video_id: ulXeKHtePDI
# Fetching transcript for video_id: 2VK_awDJ_ss
# Fetching transcript for video_id: 4wHkhxit_sU
# Fetching transcript for video_id: iXa5Bk0pu0w
# Fetching transcript for video_id: yro-CI984mE
# Fetching transcript for video_id: w9EbwjnpKaA
# Transcripts have been saved to 'Video_Transcripts.csv'.

# %%
video_details_df.head()
# Out:
#       channel_name     video_id  \
# 0  @Mrwhosetheboss  neIYdLysqlk
# 1  @Mrwhosetheboss  YX8ks42Azn8
# 2  @Mrwhosetheboss  4RcThoRG46c
# 3  @Mrwhosetheboss  vSIbvJB4WdI
# 4  @Mrwhosetheboss  cRPBp2tRxFY
#
#                                          video_title    published_datetime  \
# 0              I tested the Craziest Xiaomi Gadgets!  2024-11-13T12:04:54Z
# 1            The TRIPLE FOLDING phone has a Problem.  2024-10-26T14:06:50Z
# 2             I tested every Celebrity Tech product!  2024-10-05T10:52:18Z
# 3  iPhone 16 Pro Max vs Samsung S24 Ultra Camera ...  2024-09-19T11:44:30Z
# 4  iPhone 16 / 16 Pro Unboxing - Testing every ne...  2024-09-18T12:00:50Z
#
#    duration  view_count  like_count  dislike_count  comment_count  \
# 0  PT27M53S     6679521      219704              0           8890
# 1  PT12M54S     3464013      111736              0           5932
# 2  PT27M15S     5872358      185517              0           5921
# 3  PT16M44S     3852255      116115              0          10790
# 4  PT21M40S     4292702      125122              0           8474
#
#                                          description  \
# 0  I'm still genuinely in shock how great some of...
# 1  This phone has a LOT of good....and a LOT of b...
# 2  Celebrity tech from Ronaldo, Mbappe, Will Smit...
# 3  iPhone 16 Pro / Pro Max camera test comparison...
# 4  Unboxing and testing the iPhone 16 Pro Max, iP...
#
#                                       thumbnail_url  \
# 0  https://i.ytimg.com/vi/neIYdLysqlk/hqdefault.jpg
# 1  https://i.ytimg.com/vi/YX8ks42Azn8/hqdefault.jpg
# 2  https://i.ytimg.com/vi/4RcThoRG46c/hqdefault.jpg
# 3  https://i.ytimg.com/vi/vSIbvJB4WdI/hqdefault.jpg
# 4  https://i.ytimg.com/vi/cRPBp2tRxFY/hqdefault.jpg
#
#                                           transcript
# 0  you probably know xiaomi for their suspiciousl...
# 1  this right here is the Huawei mate XT I spent ...
# 2  in front of me right now are VTech products ma...
# 3  this is the iPhone 16 Pro Max this is the Sams...
# 4  this is the iPhone 16 the iPhone 16 plus the 1...

# %% [markdown]
# ## Adding Subscriber Count

# %%
video_details_df = pd.read_csv('Video_Details.csv')

# %%
# Function to get subscriber count for a channel
def get_subscriber_count(channel_name):
    try:
        # Search for the channel by name
        search_response = youtube.search().list(
            q=channel_name,
            type='channel',
            part='id,snippet',
            maxResults=1
        ).execute()
        
        # Get the channel ID
        channel_id = search_response['items'][0]['id']['channelId']
        
        # Get the channel details
        channel_response = youtube.channels().list(
            id=channel_id,
            part='statistics',
        ).execute()
        
        # Extract the subscriber count
        subscriber_count = channel_response['items'][0]['statistics'].get('subscriberCount', None)
        return int(subscriber_count) if subscriber_count else None
    except Exception as e:
        print(f"Error fetching data for {channel_name}: {e}")
        return None

# Read the existing dataframe
# Ensure your dataframe is loaded into `video_details_df`
# video_details_df = pd.read_csv('path_to_your_file.csv')

# Add a new column for subscriber count
video_details_df['subscriber_count'] = video_details_df['channel_name'].apply(get_subscriber_count)

# Save the updated DataFrame
#video_details_df.to_csv("Video_Details_With_Subscriber_Count.csv", index=False)

print("Subscriber count added and saved to 'Video_Details_With_Subscriber_Count.csv'.")
# Out:
# Subscriber count added and saved to 'Video_Details_With_Subscriber_Count.csv'.

# %%
video_details_df.columns
# Out:
# Index(['channel_name', 'video_id', 'video_title', 'published_datetime',
#        'duration', 'view_count', 'like_count', 'dislike_count',
#        'comment_count', 'description', 'thumbnail_url', 'subscriber_count'],
#       dtype='object')

# %%
columns = [
    'channel_name', 'subscriber_count', 'video_id', 'video_title', 'published_datetime',
    'duration', 'view_count', 'like_count', 'dislike_count',
    'comment_count', 'description', 'thumbnail_url'
]

video_details_df = video_details_df[columns]

video_details_df.to_csv("Video_Details_2.csv", index=False)

# %%
video_details_df
# Out:
#            channel_name  subscriber_count     video_id  \
# 0       @Mrwhosetheboss          20200000  neIYdLysqlk
# 1       @Mrwhosetheboss          20200000  YX8ks42Azn8
# 2       @Mrwhosetheboss          20200000  4RcThoRG46c
# 3       @Mrwhosetheboss          20200000  vSIbvJB4WdI
# 4       @Mrwhosetheboss          20200000  cRPBp2tRxFY
# 5                @mkbhd          19600000  z19HM7ANZlo
# 6                @mkbhd          19600000  Yv_S7KrOlfk
# 7                @mkbhd          19600000  nK9zxuXa3OA
# 8                @mkbhd          19600000  MRtg6A1f2Ko
# 9                @mkbhd          19600000  h3BKjZMGoIw
# 10        @unboxtherapy          24800000  hPf2qu5U6F8
# 11        @unboxtherapy          24800000  QptbdEci-m8
# 12        @unboxtherapy          24800000  _ybbXIksjUk
# 13        @unboxtherapy          24800000  G7o7Qz08RrI
# 14        @unboxtherapy          24800000  PCEmUPqSK4k
# 15              @Dave2D           3670000  b4x8boB2KdI
# 16              @Dave2D           3670000  qExcc92zHfo
# 17              @Dave2D           3670000  1rJa-0YOkwk
# 18              @Dave2D           3670000  tYJWcs-qnAc
# 19              @Dave2D           3670000  1OHZTFseggA
# 20        @MaryBautista           2040000  CHv-oKQcjF8
# 21        @MaryBautista           2040000  9a42bdlFRxM
# 22        @MaryBautista           2040000  pk9RKCRdWyc
# 23        @MaryBautista           2040000  H17T4dH7-W0
# 24        @MaryBautista           2040000  8AuAv0eQlBI
# 25  @JerryRigEverything           8980000  FZzZatxb9KQ
# 26  @JerryRigEverything           8980000  PIun_aBsRMA
# 27  @JerryRigEverything           8980000  IFthVfjoVOc
# 28  @JerryRigEverything           8980000  VS66VOUmoKQ
# 29  @JerryRigEverything           8980000  qYztDs8vPBg
# 30     @ThisIsTechToday            406000  CwaZ47RUjoU
# 31     @ThisIsTechToday            406000  TJqTr8_w588
# 32     @ThisIsTechToday            406000  ThmKbekcisg
# 33     @ThisIsTechToday            406000  ciR9HfGTlf0
# 34     @ThisIsTechToday            406000  awY7eX8rguw
# 35     @CreatedbyEllaYT            571000  ZoTCq6zunl0
# 40  PT10M52S        4559         232              0             27
# 41  PT12M48S       31718         493              0             65
# 42  PT13M21S       22931         293              0             32
# 43   PT9M30S       19716         421              0             75
# 44   PT12M8S        4030         173              0              9
#
#                                           description  \
# 0   I'm still genuinely in shock how great some of...
# 1   This phone has a LOT of good....and a LOT of b...
# 2   Celebrity tech from Ronaldo, Mbappe, Will Smit...
# 3   iPhone 16 Pro / Pro Max camera test comparison...
# 4   Unboxing and testing the iPhone 16 Pro Max, iP...
# 5   The new $599 M4 Mac Mini is really good. In mo...
# 6   Huawei Mate XT is the tri-fold phone, a concep...
# 7   Pixel 9 Pro Fold is my favorite foldable I've ...
# 8   iPhone 16 is here. Job finished? Job ain't fin...
# 9   iPhone 16 and 16 Pro have 1 change to the boxe...
# 10  The realme GT 7 Pro…The first Snapdragon 8 Eli...
# 11  Check out the New Ace Pro 2 Here - https://bit...
# 12  Apple AirPods 4 vs Apple AirPods 4 with Active...
# 13  Learn more about the new Vivo V40 Pro: https:/...
# 14  Learn more about The REDMAGIC Nova Gaming Tabl...
# 15  My review of the M4 Max MacBook Pro\n\nIf you'...
# 16  My review of the M4 Mac Mini from Apple\n\nIf ...
# 17  Thoughts on the TinyPod\nMore info - https://t...
# 18  A "review" of Apple's  iPhone 16 / Plus and iP...
# 19  My review of Apple Watch Series 10 and a look ...
# 20  Download the Home Credit App here: https://hcp...
# 21  Follow me here!\nInstagram: https://www.instag...
# 22  Watch how the EliteBook 840 G11’s features add...
# 23  Where to get it:\nHOT 50 Pro+\nSRP: 8,499\nTTS...
# 24  Follow me here!\nInstagram: https://www.instag...
# 25  It is time to durability test the regular iPho...
# 26  The Triple Folding Smartphone From Huawei is h...
# 27  The brand new Red Magic NOVA just arrived. Wit...
# 28  Does the new Black Titanium Apple Watch Ultra ...
# 29  Today we durability test the new iPhone 16 Pro...
# 30  In this in-depth review, I test the new Apple ...
# 31  The Apple iPhone 16 Pro Max is Apple's most po...
# 32  The Nothing Ear (open) is an outer-ear open-ea...
# 33  The Apple iPhone 16 Pro Max has a new camera c...
# 34  The OnePlus Buds Pro 3 is the latest release f...
# 35  Apple Intelligence is finally here. Does it co...
# 36  Check out the Samsung S95D TV here: https://ww...
# 37  Check out the Lenovo Yoga series here: https:/...
# 38  I compared the latest products from Samsung an...
# 39  This is my review of the Samsung Galaxy Z Flip...
# 40  Want to know if the BuzzTV Powerstation 6 is a...
# 41  Get a first look at the 2024 MacBook Pro M4 in...
# 42  In this video, we're putting the Xiaomi Redmi ...
# 43  Take your streaming experience to the next lev...
# 44  GEEKOM GT13 Pro\n✅ Official:   https://bit.ly/...
#
#                                        thumbnail_url
# 0   https://i.ytimg.com/vi/neIYdLysqlk/hqdefault.jpg
# 1   https://i.ytimg.com/vi/YX8ks42Azn8/hqdefault.jpg
# 2   https://i.ytimg.com/vi/4RcThoRG46c/hqdefault.jpg
# 3   https://i.ytimg.com/vi/vSIbvJB4WdI/hqdefault.jpg
# 4   https://i.ytimg.com/vi/cRPBp2tRxFY/hqdefault.jpg
